# %%
# %load_ext autoreload
# %autoreload 2

# %%
import time
from collections import defaultdict

from utils import plot_model_trajectories
from utils import ENV3

from models.env3 import Random, MostExpensive, LogReg, SVCModel

from tqdm import tqdm_notebook

import config

# %matplotlib inline

# %%
results = defaultdict(list) # modelname : list  with shape n_runs x n_steps

# %%
# %%time
ENV_URL = config.ENV3_URL
KEY = config.KEY

env = ENV3(key=KEY, url=ENV_URL)

n_runs = 3
n_steps = 100

models = {
    'Random' : Random(),
    'MostExpensive' : MostExpensive(),
    'LogReg' : LogReg(),
    'LogReg_retrain20' : LogReg(retrain=20),
    'LogReg*price' : LogReg(price_reweight=True),
    'LogReg*price_retrain20' : LogReg(price_reweight=True, retrain=20),
     'SVC' : SVCModel(),
    'SVC_retrain20' : SVCModel(retrain=20),
    'SVC*price' : SVCModel(price_reweight=True),
    'SVC*price_retrain20' : SVCModel(price_reweight=True, retrain=20),
    
}

for model_name, model in models.items():
    
    for n in tqdm_notebook(range(n_runs), desc=model_name, leave=True, position=0):
        # init model 
        history = env.reset()
        model.train(history)
        input_data = {
            'state' : history['next_state']
        }
        
        rewards = []
        for _ in tqdm_notebook(range(n_steps), desc='run %d' % n, leave=False, position=1):
            time.sleep(0.05)
            
            prediction = model.predict(input_data)
            res = env.predict(prediction) # get res for prediction
            
            input_data = {
                'state' : res['state']
            }
            reward = res['reward']
            rewards.append(reward)
            
        results[model_name + '_' + time.strftime('%H:%M')].append(rewards)
# Out:
# HBox(children=(IntProgress(value=0, description='Random', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 0'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 1'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 2'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='MostExpensive', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 0'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 1'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 2'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='LogReg', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 0'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 1'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 2'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='LogReg_retrain20', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 0'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 1'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 2'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='LogReg*price', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 0'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 1'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 2'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='LogReg*price_retrain20', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 0'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 1'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 2'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='SVC', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 0'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 1'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 2'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='SVC_retrain20', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 0'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 1'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 2'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='SVC*price', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 0'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 1'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 2'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='SVC*price_retrain20', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 0'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 1'), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='run 2'), HTML(value='')))
# CPU times: user 23.7 s, sys: 1.66 s, total: 25.3 s
# Wall time: 4min 47s

# %%
plot_model_trajectories(results)
# Out:
#                            Model  Score  Conversion Rate
# 8   LogReg*price_retrain20_17:04  34496         0.385000
# 12               SVC*price_17:05  28294         0.353333
# 13     SVC*price_retrain20_17:05  27469         0.323333
# 6             LogReg*price_17:03  24795         0.293333
# 3                   LogReg_17:02  22969         0.363333
# 7   LogReg*price_retrain20_17:03  21285         0.270000
# 2            MostExpensive_17:02  20777         0.210000
# 9                      SVC_17:04  17435         0.326667
# 11           SVC_retrain20_17:05  16148         0.380000
# 4         LogReg_retrain20_17:02  15930         0.280000
# 10           SVC_retrain20_17:04  12848         0.345000
# 0                   Random_17:01  12142         0.270000
# 5         LogReg_retrain20_17:03  10886         0.405000
# 1            MostExpensive_17:01  10799         0.110000

# %%
plot_model_trajectories(results)
# Out:
#                            Model  Score  Conversion Rate
# 6             LogReg*price_16:46  35078         0.390000
# 7   LogReg*price_retrain20_16:48  31072         0.340000
# 11     SVC*price_retrain20_16:53  28073         0.310000
# 10               SVC*price_16:53  27402         0.313333
# 2            MostExpensive_16:21  26687         0.275000
# 1            MostExpensive_16:20  26093         0.270000
# 9            SVC_retrain20_16:52  21105         0.386667
# 5         LogReg_retrain20_16:45  14920         0.430000
# 3                   LogReg_16:44  14735         0.380000
# 4                   LogReg_16:45  14345         0.405000
# 0                   Random_16:20  13118         0.283333
# 8                      SVC_16:52  10765         0.276667
